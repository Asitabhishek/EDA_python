# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv("Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %% [markdown]
# **Box Plot**
#
# - Box plot is used to identify the outlier
#
#
# - outlier is an obsrvation having huge value or huge negative value
#
# - Q1 = 25p ,Q2 = 50 ,Q3 =75
#
# - IQR= INTER quartile range=Q3-Q1
#
# - Q3+1.5*IQR and Q1-1.5*IQR
# -

# %%
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.title('Boxplot')
plt.xlabel('Wages')
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
sns.boxplot(wage_data,orient='h')
plt.title('Boxplot')
plt.xlabel('Wages')
plt.show()

# %%
plt.figure(figsize=(14,3))
plt.suptitle("Comparision of histogram with Boxplot")
plt.subplot(1,2,1)
plt.hist(wage_data,bins=20)
plt.xlabel('histogram')
plt.subplot(1,2,2)
plt.boxplot(wage_data,vert=False)
plt.xlabel('Boxplot')
plt.show()

# %%
plt.figure(figsize=(14,3))
plt.suptitle("Comparision of histogram with Boxplot")
plt.subplot(1,2,1).hist(wage_data,bins=20)
plt.xlabel('histogram')
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.xlabel('Boxplot')
plt.show()

# %% [markdown]
# **finding the outliers**
#
# - we already know that outlier available less than Q1-1.5*IQR and Q3+1.5*IQR
#
# -

# %%
wage_data=visa_df['prevailing_wage']
Q1=np.percentile(wage_data,25)
Q2=np.percentile(wage_data,50)
Q3=np.percentile(wage_data,100)
IQR=Q3-Q1
LB=Q1-1.5*IQR
UB=Q3+1.5*IQR
con1=wage_data<LB
con2=wage_data>UB
con3=con1|con2
outlier_data=wage_data[con3]
outlier_data
# Out:
# Series([], Name: prevailing_wage, dtype: float64)

# %%
Q1=np.percentile(wage_data,25)
Q1
# Out:
# 34015.479999999996

# %%
Q2=np.percentile(wage_data,50)
Q2
# Out:
# 70308.20999999999

# %%
Q3=np.percentile(wage_data,100)
Q3
# Out:
# 319210.27

# %%
IQR=Q3-Q1
IQR
# Out:
# 285194.79000000004

# %%
LB=Q1-1.5*IQR
LB
# Out:
# -393776.7050000001

# %%
UB=Q3+1.5*IQR
UB
# Out:
# 747002.4550000001

# %%
con1=wage_data<LB
con2=wage_data>UB
con3=con1|con2

# %%
outlier_data=wage_data[con3]
outlier_data
# Out:
# Series([], Name: prevailing_wage, dtype: float64)

# %%
wage_data=visa_df['prevailing_wage']
Q1=np.percentile(wage_data,25)
Q2=np.percentile(wage_data,50)
Q3=np.percentile(wage_data,100)
IQR=Q3-Q1
LB=Q1-1.5*IQR
UB=Q3+1.5*IQR
con1=wage_data<LB
con2=wage_data>UB
con3=con1|con2
outlier_data=wage_data[con3]
outlier_data
# Out:
# Series([], Name: prevailing_wage, dtype: float64)

# %%
wage_data = visa_df['prevailing_wage']
Q1 = np.percentile(wage_data, 25)
Q3 = np.percentile(wage_data, 75)
IQR = Q3 - Q1
LB = Q1 - 1.5 * IQR
UB = Q3 + 1.5 * IQR

con1 = wage_data < LB
con2 = wage_data > UB
con3 = con1 | con2

outlier_data = wage_data[con3]
outlier_data
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
# wage_data = visa_df['prevailing_wage']
# Q1 = np.percentile(wage_data, 25)
# Q3 = np.percentile(wage_data, 75)
# IQR = Q3 - Q1
# LB = Q1 - 1.5 * IQR
# UB = Q3 + 1.5 * IQR

# con1 = wage_data < LB
# con2 = wage_data > UB
# con3 = con1&con2
# non_outlier_df=visa_df[con3]
# non_outlier_df

# %%
wage_data = visa_df['prevailing_wage']
Q1 = np.percentile(wage_data, 25)
Q3 = np.percentile(wage_data, 75)
IQR = Q3 - Q1
LB = Q1 - 1.5 * IQR
UB = Q3 + 1.5 * IQR

con1 = wage_data < LB
con2 = wage_data > UB
con3 = con1 | con2

# To get the dataframe with non-outlier data
non_outlier_df = visa_df[~con3]
non_outlier_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
wage_data_non_outlier=non_outlier_df['prevailing_wage']
wage_data=visa_df['prevailing_wage']
plt.figure(figsize=(14,8))
plt.suptitle("Comparision of histogram with Boxplot")
plt.subplot(2,2,1).hist(wage_data_non_outlier,bins=20)
plt.xlabel('histogram')
plt.subplot(2,2,2).boxplot(wage_data_non_outlier,vert=False)
plt.xlabel('Boxplot')
plt.subplot(2,2,3).hist(wage_data,bins=20)
plt.xlabel('histogram')
plt.subplot(2,2,4).boxplot(wage_data,vert=False)
plt.xlabel('Boxplot')
plt.show()

# %%
# fill the out

# %%
wage_data_non_outlier=non_outlier_df['prevailing_wage']
wage_data=visa_df['prevailing_wage']
plt.figure(figsize=(14,8))
plt.hist(wage_data)
plt.hist(wage_data_non_outlier)
plt.show()

# %% [markdown]
# **how to deal with outliers**
# - 1. we can drop the outliers
#   - Droping outlier is an easy task,but not recommended
#   - if youndrop the outliers we are dropping the row
#   - which means we are droping the other columns value also
#   - may be some important we might loss from other column values
#   - but in industry if outlier percentage less than 2% of the total data ,we can drop
#   - the number of outlier in pwage is 427
#   - the number of total observation are 25480
#   - the percentage is 1.6 less than 2%
#   2. we already know that outliers does not affect by median
#   - so it is the best pratice to fill the outliers with median
#   3. capping or flooring
#   - insted of fill with median
#   - we can fill with certain values
#   - the outliers which are less than LB fill with LB value
#   - the outlier which are greater than Ub fill with LB
# - isolation Forest
#   - is ML model is used to find the outlier and anamolies

# %% [markdown]
# **Fill with Median Value**

# %% [markdown]
# **np.where**
# - in numpy we have method called where
# - it takes three arguments
#   1. Condition
#   2. value if condition is True
#   3. value if condition is False
# - it is applicable for only binary means if and else

# %%
list1=[]
for value in wage_data:
    if value < LB or value > UB:
        median= wage_data.median()
        list1.append(median)
    else:
        list1.append(value)

# %%
dict1={'Sub':['DS','DE','CS'],'marks':[100,200,300]}
df=pd.DataFrame(dict1)
df
# Out:
#   Sub  marks
# 0  DS    100
# 1  DE    200
# 2  CS    300

# %%
con=df['marks']>100
l=np.where(con,1,df['marks'])
df['marks']=l
df
# Out:
#   Sub  marks
# 0  DS    100
# 1  DE      1
# 2  CS      1

# %%
wage_data=visa_df['prevailing_wage']
con1= wage_data<LB
con2=wage_data>UB
con=con1 | con2
wage_med=wage_data.median()
l=np.where(con,wage_med,wage_data)
l
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
visa_df['prevailing_wage_update']=l

# %%
plt.subplot(1,2,1).boxplot(visa_df['prevailing_wage_update'])
plt.subplot(1,2,2).hist(visa_df['prevailing_wage_update'])
# Out:
# (array([4580., 3368., 3890., 4369., 3507., 2860., 1643.,  706.,  295.,
#          262.]),
#  array([2.13670000e+00, 2.18113840e+04, 4.36206314e+04, 6.54298787e+04,
#         8.72391260e+04, 1.09048373e+05, 1.30857621e+05, 1.52666868e+05,
#         1.74476115e+05, 1.96285363e+05, 2.18094610e+05]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **BI variate analysis**
# - We already seen uni variat analysis
# - we performed the categorical column analysis
#   - frequency table
#   - bar chart
#   - relative frequency table(value counts normalized form)
#   - pie chart
# - we prformed the numerical column analysis
#   - histogram
#   - Distribution plot
#   - box plot
#   - outlier analysis
#   - filling the out lier
# - Now we will do Categorical-categorical Analysis
# - numerical-numerical analysis
# - categorical-numerical analysis

# %% [markdown]
# **Categorical - categorical**
# - lets consider two columns
#   - continent
#   - case status

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %% [markdown]
# **task**
# - find the certified observation continent wise
# - find the denied observation continent wise

# %%
#step-1:Make the first condition continent=='Asia'
#step-2:make the second condition case_status =='certified'
#step-3:make the third condition:con1&con2
#step-4:then retrive the datat frame and take the count

# %%
con1=visa_df['continent']=='Asia'
con2=visa_df['case_status']=='Certified'
con3=con1&con2
len(visa_df[con3])
# Out:
# 11012

# %%
continents=visa_df['continent'].unique()
for i in continents:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con3=con1&con2
    count=len(visa_df[con3])
    print(f'the number of certifid visa from {i} is:{count}')
# Out:
# the number of certifid visa from Asia is:11012
# the number of certifid visa from Africa is:397
# the number of certifid visa from North America is:2037
# the number of certifid visa from Europe is:2957
# the number of certifid visa from South America is:493
# the number of certifid visa from Oceania is:122

# %%
continents=visa_df['continent'].unique()
certified_list,denied_list=[],[]
for i in continents:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con3=visa_df['case_status']=='Denied'
    cert_con=con1&con2
    den_con=con1&con3
    cert_count=len(visa_df[cert_con])
    den_count=len(visa_df[den_con])
    print(f'the number of certified visa from {i} is:{cert_count}')
    print(f'the number of denied visa from {i} is:{den_count}')
# Out:
# the number of certified visa from Asia is:11012
# the number of denied visa from Asia is:5849
# the number of certified visa from Africa is:397
# the number of denied visa from Africa is:154
# the number of certified visa from North America is:2037
# the number of denied visa from North America is:1255
# the number of certified visa from Europe is:2957
# the number of denied visa from Europe is:775
# the number of certified visa from South America is:493
# the number of denied visa from South America is:359
# the number of certified visa from Oceania is:122
# the number of denied visa from Oceania is:70

# %% [markdown]
# **Cross tab**
# - The above data frame we can make by using a method: **cross tab**
# - it is avalible in pandas
# - it taks two argumnets
#   - index
#   - column
# - in the above dataframe index column is :continent
# - in the above dataframe data column is :case_status

# %%
pd.crosstab(visa_df['continent'],visa_df['case_status'])
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
idx_column=visa_df['continent']
data_column=visa_df['case_status']
df4=pd.crosstab(idx_column,data_column)
df4
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
df4.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# **Multivariant Analysis**
# - Education
# - Continent
# - case Status
# - we already know from Asia there are 11k Accepted visa
# - in that i want further break down based on education
# - here also pd.cross tab
#   - first fix your index

# %%
idx_column=visa_df['continent']
data_column=[visa_df['education_of_employee'],visa_df['case_status']]
df5=pd.crosstab(idx_column,data_column)
df5
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
df5.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# **Numerical vs Numerical**
# - to understand Numerical column relation we need to plot scatter plots
# - scatterplot gives the relation between two numerical columns
# - Bar chart-pie chart-histograms-scatter plots
# - scatter plots under matplotlib packages
# - plt.scatter

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x=[i for i in range (-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
# step-1: read one numerical column
#step-2: read another numerical column
#step-3:apply the scatter plot

# %%
pd.DataFrame(zip(x,y))
# Out:
#      0    1
# 0  -10  100
# 1   -9   81
# 2   -8   64
# 3   -7   49
# 4   -6   36
# 5   -5   25
# 6   -4   16
# 7   -3    9
# 8   -2    4
# 9   -1    1
# 10   0    0
# 11   1    1
# 12   2    4
# 13   3    9
# 14   4   16
# 15   5   25
# 16   6   36
# 17   7   49
# 18   8   64
# 19   9   81
# 20  10  100

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
col1=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
col3=visa_df['prevailing_wage']
plt.figure(figsize=(14,5))
plt.subplot(1,3,1).scatter(col1,col2)
plt.xlabel('no_of_employees')
plt.ylabel('yr_of_estab')
plt.subplot(1,3,2).scatter(col1,col3)
plt.subplot(1,3,3).scatter(col2,col3)

# %%
- implemnt th covariance function
- covariance vs correlation
  - covariance

# %% [markdown]
# **mthod name:corr**

# %%
visa_df.corr(numeric_only=True)
# Out:
#                         no_of_employees  yr_of_estab  prevailing_wage  \
# no_of_employees                1.000000    -0.017770        -0.009523
# yr_of_estab                   -0.017770     1.000000         0.012342
# prevailing_wage               -0.009523     0.012342         1.000000
# prevailing_wage_update        -0.006762     0.015885         0.900557
#
#                         prevailing_wage_update
# no_of_employees                      -0.006762
# yr_of_estab                           0.015885
# prevailing_wage                       0.900557
# prevailing_wage_update                1.000000

# %% [markdown]
# **Heat map**
# - Heat map is one of the important visualization method , to show th matrix
# - it is under **seaborn** package
# - in every matrix we have highest values and lowest value available
# - Heat map will give colour visualization
# - also it provides color bar

# %%
corr_bar=visa_df.corr(numeric_only=True)
sns.heatmap(corr_bar,annot=True,cmap='Greens')
plt.show()

# %%
- By seeing the graph we might not says the relation status
- it is the best pratice get the percentage of relation using co relation 
- all three columns having approximately zero percentage of relation
- which indicates all the column having no relation
- no relation means independent each other 
- in ML we except the imput columns should independent each other
- corr gives
