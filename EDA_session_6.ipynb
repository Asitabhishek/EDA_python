# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv("Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **Encoding**
# - Encoding means convert categorical columns data to Numerical data
# - Because ML model Except the data should be in Numerical format
# - ML model developed by math algorithm
# - it is very important to apply encoding
# - the following method are
#   - map
#   - np.where
#   - one hot encoding
#   - lable encoder

# %% [markdown]
# **Map Method**
# - Map is one method to convert categorical value to numerical value
# - take one categorical column
# - get the unique lable first
# - make a dictionary with assign a nuhmber to each lable
# - for example case status has two lables
#   - certified
#   - denied
# - Assign 0 to certified, 1 to denined
# - Crate a Dictionary lable as keys, number as values only
# - {'Certified':'Denined':1}

# %%
#step-1:read the column
#step-1:get the unique lables
#step-1:make a dictionary
#step-1:apply the map

# %%
visa_df['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %%
# i want to apply the map method for all catgorical column

# %%
unique_lables=sorted(visa_df['case_status'].unique())
list1=[i for i in range (len(unique_lables))]
dict1=dict(zip(unique_lables,list1))
dict1
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
{key:value for key,value in zip(unique_lables,list1)}
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv("Visadataset.csv")
unique_lables=sorted(visa_df['case_status'].unique())
list1=[i for i in range (len(unique_lables))]
dict1=dict(zip(unique_lables,list1))
dict1
visa_df['case_status1']=visa_df['case_status'].map(dict1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv("Visadataset.csv")
cat_columns=visa_df.select_dtypes(include='object').columns
for i in cat_columns:
    unique_lables=sorted(visa_df[i].unique())
    list1=[i for i in range (len(unique_lables))]
    dict1=dict(zip(unique_lables,list1))
    dict1
    visa_df[i]=visa_df[i].map(dict1)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **Lable Encoder**
# - Lable Encoder is a method to convert categorical data to numerical data
# - the for loop method we explored
# - But the lable encoder also do the same
# - It is under **sickit-learn** we usually called as **sklearn**
# - under sklearn we have a method

# %%
visa_df=pd.read_csv("Visadataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
cat_columns=visa_df.select_dtypes(include='object').columns
le=LabelEncoder()
for i in cat_columns:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **Fit and Transform**
#
# - fit mans develope the logic
#
# - trsnsform means process the logics
#
# - if we observe in map method first we have developd dictionary logic
#
# - then we apply that dictionarnhy column
#
# - dveloping th dictionary is kind of fit
#
# - apply the dictionary to the column means we are transforming the data cat to num
#
# - whenever we ar transforming or cahnging the data then use fit Transform
#
# - if we are not changing the data then only fit
# -

# %% [markdown]
# **np.where**
#
# - using np.where also we can change the categorical data to numerical data
#
# - np.where is same as if else
#
# - if condition is True: will apply true value
#
# - if condition is False :will apply false value
#
# - so np.where us for only binary lables
#
# - A column should have only two unique lable
# -

# %%
visa_df=pd.read_csv("Visadataset.csv")
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **one hot Encoder**
# - one hot means if one will be on ,another will be off
# - On represents with 1
# - off Represents with 0
# - For example case status has two unique lables
#   - Certified
#   - Denined
# - one hot encoders create nww columns which is equal to number of unique lables
# - for example case status will create two nwe extra columns
#   - Case_status_certified
#   - case_status_denined
